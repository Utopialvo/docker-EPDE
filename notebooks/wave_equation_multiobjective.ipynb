# %%
import os
import sys

#sys.path.append('../')
#sys.path.pop()
#sys.path.append(os.path.abspath(os.path.join(os.path.dirname( __file__ ), '..')))

import numpy as np
import epde.interface.interface as epde_alg

from epde.interface.prepared_tokens import CustomTokens, CacheStoredTokens, TrigonometricTokens


'''

Loading data, representing the wave equation solution and moving the time axis into 
the first position. 

'''

data_file = 'EPDE/examples/data/wave_sln_80.csv'
data = np.loadtxt(data_file, delimiter = ',').T

'''
Defining grids and boundary for the domain. The grids can be (and will be) 
used as a separate family of tokens and is necessary, when we add functions,
dependent on the coordinates, such as trigonometric functions, into the pool.
Also, we specify boundary for the domain: the derivatives near the domain 
boundary tend to have high computational errors.
'''

t = np.linspace(0, 1, 81); x = np.linspace(0, 1, 81)

boundary = 20
dimensionality = data.ndim - 1   
grids = np.meshgrid(t, x, indexing = 'ij')

'''
Here, we define the object, dedicated to the equation search: among the 
initialization arguments, the most important include dimensionality (here we 
must pass the dimensionality of the input dataset), and number of the equation 
search iterations. Multiobjective mode flag controls the optimization procedure: if it is False, 
the algorithm executes a singleobjective optimization, detecting only a single best candidate equation from the 
point of process representation. Otherwise, in multi-objective optimization mode, a Pareto frontier, 
containing solutions, "best", according to selected metrics (that are complexity and quality) is detected.
'''

multiobjective_mode = True
epde_search_obj = epde_alg.EpdeSearch(multiobjective_mode=multiobjective_mode, use_solver = False, 
                                      dimensionality = dimensionality, boundary = 10,
                                      coordinate_tensors = grids)

'''
Setting memory usage for cache stored tokens and terms (that are the ones, that 
are saved after initial calculations during algorithm operations to avoid 
redundant computations).
To prepare for the equation search, data can be denoised, and derivatives have to be computed. 
Here by .set_preprocessor() we set ANN-based data smoothing, and from that ANN values, the derivatives 
are calculated, using finite differences. By default, Chebyshev polynomials (default_preprocessor_type='poly') 
are used to represent the data, and their analytical derivativs are used in algorithm.

Next, specifying parameters of the optimization algorithm, such as number of epochs and population size,
with .set_multiobjective_params(). 
'''

epde_search_obj.set_preprocessor(default_preprocessor_type='ANN', preprocessor_kwargs={'epochs_max' : 10000})

popsize = 7
if multiobjective_mode:
    epde_search_obj.set_moeadd_params(population_size = popsize, 
                                      training_epochs=40)
else:
    epde_search_obj.set_singleobjective_params(population_size = popsize, 
                                               training_epochs=40)
'''
Next, we can define tokens, containing grid, so our discovered equation can have 
terms like "t * du/dt". Here, we operate on the synthetic data and we do 
not expect their presence in the desired equation. However, they can be present
in an equation, describing some real-world data, thus we provide a tool for their
inclusion.

To increase the pool size and artificially complicate the equation search problem, we
can include trigonometric tokens.

'''


custom_grid_tokens = CacheStoredTokens(token_type = 'grid',
                                       token_labels = ['t', 'x'],
                                       token_tensors={'t' : grids[0], 'x' : grids[1]},
                                       params_ranges = {'power' : (1, 1)},
                                       params_equality_ranges = None)

trig_tokens = TrigonometricTokens(dimensionality = dimensionality)

'''
Method epde_search.fit() is used to initiate the equation search.
'''

factors_max_number = {'factors_num' : [1, 2], 'probas' : [0.8, 0.2]}

opt_val = 1e-1
bounds = (1e-8, 1e0) if multiobjective_mode else (opt_val, opt_val)    
epde_search_obj.fit(data=data, variable_names=['u',], max_deriv_order=(2, 2),
                    equation_terms_max_number=5, data_fun_pow = 1, additional_tokens=[trig_tokens, custom_grid_tokens], 
                    equation_factors_max_number=factors_max_number,
                    eq_sparsity_interval=bounds)

'''
The results of the equation search have the following format: if we call method 
.equation_search_results() with "only_print = True", the Pareto frontiers 
of equations of varying complexities will be shown, as in the following example:
    
  0-th non-dominated level


0.0 * du/dx2{power: 1.0} * sin{power: 1.0, freq: 2.252595303418488, dim: 0.0} + 0.0 * du/dx2{power: 1.0} +
+ 0.8160919569329641 * du/dx1{power: 1.0} * sin{power: 1.0, freq: 1.6199200064309462, dim: 0.0} + 
- 0.024782817001144604 * d^2u/dx1^2{power: 1.0} + -0.019959546715405427 =
= du/dx1{power: 1.0} * t{power: 1.0}
{'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False,
                                                                             'value': {'factors_num': [1, 2], 'probas': [0.8, 0.2]}}, 
 ('sparsity', 'u'): {'optimizable': True, 'value': 0.08798494856061533}} ,
with objective function values of [1.5624243 5.       ] 

0.0 * du/dx2{power: 1.0} * sin{power: 1.0, freq: 2.252595303418488, dim: 0.0} + 0.0 * du/dx2{power: 1.0} +
+ 0.04069650032520592 * d^2u/dx2^2{power: 1.0} + 0.0 * du/dx1{power: 1.0} + 0.05192304919178248 =
= d^2u/dx1^2{power: 1.0}
{'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 
                                                                             'value': {'factors_num': [1, 2], 'probas': [0.8, 0.2]}}, 
 ('sparsity', 'u'): {'optimizable': True, 'value': 0.08201621478905675}},
with objective function values of [12.91522339  2.        ] 
    
0.0 * d^2u/dx1^2{power: 1.0} * du/dx2{power: 1.0} + 0.6611044289299713 * du/dx1{power: 1.0} + 0.0 * u{power: 1.0} +
+ 0.0 * du/dx2{power: 1.0} * sin{power: 1.0, freq: 2.252595303418488, dim: 0.0} + 0.01362536696256267 =
= du/dx1{power: 1.0} * t{power: 1.0}
{'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 
                                                                             'value': {'factors_num': [1, 2], 'probas': [0.8, 0.2]}}, 
 ('sparsity', 'u'): {'optimizable': True, 'value': 0.07814228353695334}},
with objective function values of [6.23159201 3.        ] 

0.0 * d^2u/dx2^2{power: 1.0} + 0.0 * du/dx1{power: 1.0} * u{power: 1.0} +
+ 0.0 * du/dx1{power: 1.0} + 0.0 * d^2u/dx1^2{power: 1.0} + 0.0 = du/dx2{power: 1.0}
{'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 
                                                                             'value': {'factors_num': [1, 2], 'probas': [0.8, 0.2]}},
 ('sparsity', 'u'): {'optimizable': True, 'value': 0.07430960217896924}},
with objective function values of [2.38758376e+03 1.00000000e+00] 
'''

epde_search_obj.equation_search_results(only_print=True, num = 1)
# Out:
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7fc90f788bb0>
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7fc90f788bb0>
# trig_token_params: VALUES = (0, 1)
# Deriv orders after definition [[None], [0], [0, 0], [1], [1, 1]]
# Surface training t=0, loss=3.399463653564453
# Surface training t=1, loss=3.3452534675598145
# Surface training t=2, loss=3.298815369606018
# Surface training t=3, loss=3.180923819541931
# Surface training t=4, loss=3.1196917295455933
# Surface training t=5, loss=3.035775303840637
# Surface training t=6, loss=2.9571613073349
# Surface training t=7, loss=2.8511369228363037
# Surface training t=8, loss=2.7691197395324707
# Surface training t=9, loss=2.7132155895233154
# Surface training t=10, loss=2.6188379526138306
# Surface training t=11, loss=2.540230631828308
# Surface training t=12, loss=2.45063316822052
# Surface training t=13, loss=2.3731924295425415
# Surface training t=14, loss=2.2897822856903076
# Surface training t=15, loss=2.1805962324142456
# Surface training t=16, loss=2.111740469932556
# Surface training t=17, loss=2.0370192527770996
# Surface training t=18, loss=1.9641979932785034
# Surface training t=19, loss=1.9002239108085632
# Surface training t=20, loss=1.8458194136619568
# Surface training t=21, loss=1.7728367447853088
# Surface training t=22, loss=1.7372812628746033
# Surface training t=23, loss=1.720126211643219
# Surface training t=24, loss=1.7177167534828186
# Surface training t=25, loss=1.694121539592743
# Surface training t=26, loss=1.6855458617210388
# Surface training t=27, loss=1.6698602437973022
# Surface training t=28, loss=1.6942535638809204
# Surface training t=29, loss=1.673176348209381
# Surface training t=30, loss=1.6860299110412598
# Surface training t=31, loss=1.686808168888092
# Surface training t=32, loss=1.6955236792564392
# Surface training t=33, loss=1.6888219118118286
# Surface training t=34, loss=1.6703141331672668
# Surface training t=35, loss=1.711590588092804
# Surface training t=36, loss=1.6848896741867065
# Surface training t=37, loss=1.7013744115829468
# Surface training t=38, loss=1.6877663135528564
# Surface training t=39, loss=1.688654363155365
# Surface training t=40, loss=1.6903581619262695
# Surface training t=41, loss=1.683225929737091
# Surface training t=42, loss=1.6712606549263
# Surface training t=43, loss=1.6779664158821106
# Surface training t=44, loss=1.6708175539970398
# Surface training t=45, loss=1.6917498111724854
# Surface training t=46, loss=1.6804238557815552
# Surface training t=47, loss=1.6777809262275696
# Surface training t=48, loss=1.681074321269989
# Surface training t=49, loss=1.687434196472168
# Surface training t=50, loss=1.6946809887886047
# Surface training t=51, loss=1.686955213546753
# Surface training t=52, loss=1.6783507466316223
# Surface training t=53, loss=1.6788315176963806
# Surface training t=54, loss=1.6812615990638733
# Surface training t=55, loss=1.676600158214569
# Surface training t=56, loss=1.6651207208633423
# Surface training t=57, loss=1.6698222756385803
# Surface training t=58, loss=1.660892367362976
# Surface training t=59, loss=1.6856709718704224
# Surface training t=60, loss=1.6612892746925354
# Surface training t=61, loss=1.6711934804916382
# Surface training t=62, loss=1.6745091080665588
# Surface training t=63, loss=1.672514259815216
# Surface training t=64, loss=1.670888602733612
# Surface training t=65, loss=1.6816354990005493
# Surface training t=66, loss=1.6710166335105896
# Surface training t=67, loss=1.6793983578681946
# Surface training t=68, loss=1.6733237504959106
# Surface training t=69, loss=1.6755645275115967
# Surface training t=70, loss=1.6708457469940186
# Surface training t=71, loss=1.6740665435791016
# Surface training t=72, loss=1.6666688919067383
# Surface training t=73, loss=1.6642058491706848
# Surface training t=74, loss=1.6611976027488708
# Surface training t=75, loss=1.651141107082367
# Surface training t=76, loss=1.6705753207206726
# Surface training t=77, loss=1.6659192442893982
# Surface training t=78, loss=1.659971833229065
# Surface training t=79, loss=1.665611207485199
# Surface training t=80, loss=1.6805097460746765
# Surface training t=81, loss=1.6521340608596802
# Surface training t=82, loss=1.6551923155784607
# Surface training t=83, loss=1.6752079725265503
# Surface training t=84, loss=1.656809151172638
# Surface training t=85, loss=1.6711100339889526
# Surface training t=86, loss=1.6393905282020569
# Surface training t=87, loss=1.6538320779800415
# Surface training t=88, loss=1.6405044794082642
# Surface training t=89, loss=1.6259931325912476
# Surface training t=90, loss=1.6501346230506897
# Surface training t=91, loss=1.6599149107933044
# Surface training t=92, loss=1.6429890990257263
# Surface training t=93, loss=1.662722110748291
# Surface training t=94, loss=1.6374009847640991
# Surface training t=95, loss=1.6454387307167053
# Surface training t=96, loss=1.637903094291687
# Surface training t=97, loss=1.635268211364746
# Surface training t=98, loss=1.6278762221336365
# Surface training t=99, loss=1.6233998537063599
# Surface training t=100, loss=1.6352984309196472
# Surface training t=101, loss=1.627926766872406
# Surface training t=102, loss=1.6152074933052063
# Surface training t=103, loss=1.6268056631088257
# Surface training t=104, loss=1.6293251514434814
# Surface training t=105, loss=1.6324023008346558
# Surface training t=106, loss=1.6300328969955444
# Surface training t=107, loss=1.6120954155921936
# Surface training t=108, loss=1.5946540832519531
# Surface training t=109, loss=1.6053304076194763
# Surface training t=110, loss=1.6210273504257202
# Surface training t=111, loss=1.5828238129615784
# Surface training t=112, loss=1.6056134700775146
# Surface training t=113, loss=1.5961283445358276
# Surface training t=114, loss=1.5906853079795837
# Surface training t=115, loss=1.5923488140106201
# Surface training t=116, loss=1.5694159269332886
# Surface training t=117, loss=1.566770315170288
# Surface training t=118, loss=1.563345730304718
# Surface training t=119, loss=1.5738279819488525
# Surface training t=120, loss=1.5567364692687988
# Surface training t=121, loss=1.530775010585785
# Surface training t=122, loss=1.5153624415397644
# Surface training t=123, loss=1.5411503314971924
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 104
#     102 opt_val = 1e-1
#     103 bounds = (1e-8, 1e0) if multiobjective_mode else (opt_val, opt_val)
# --> 104 epde_search_obj.fit(data=data, variable_names=['u',], max_deriv_order=(2, 2),
#     105                     equation_terms_max_number=5, data_fun_pow = 1, additional_tokens=[trig_tokens, custom_grid_tokens],
#     106                     equation_factors_max_number=factors_max_number,
#     107                     eq_sparsity_interval=bounds)
#     109 '''
#     110 The results of the equation search have the following format: if we call method
#     111 .equation_search_results() with "only_print = True", the Pareto frontiers
#    (...)
#     147 with objective function values of [2.38758376e+03 1.00000000e+00]
#     148 '''
#     150 epde_search_obj.equation_search_results(only_print=True, num = 1)
#
# File ~/dwn/newenv/lib/python3.10/site-packages/epde/interface/interface.py:628, in EpdeSearch.fit(self, data, equation_terms_max_number, equation_factors_max_number, variable_names, eq_sparsity_interval, derivs, max_deriv_order, additional_tokens, data_fun_pow)
#     624 cur_params = {'variable_names' : variable_names, 'max_deriv_order' : max_deriv_order,
#     625               'additional_tokens' : [family.token_family.ftype for family in additional_tokens]}
#     627 if self.pool == None or self.pool_params != cur_params:
# --> 628         self.create_pool(data = data, variable_names=variable_names,
#     629                          derivs=derivs, max_deriv_order=max_deriv_order,
#     630                          additional_tokens=additional_tokens,
#     631                          data_fun_pow=data_fun_pow)
#     633 self.optimizer_init_params['population_instruct'] = {"pool": self.pool, "terms_number": equation_terms_max_number,
#     634                                                      "max_factors_in_term": equation_factors_max_number,
#     635                                                      "sparsity_interval": eq_sparsity_interval}
#     637 if self.multiobjective_mode:
#
# File ~/dwn/newenv/lib/python3.10/site-packages/epde/interface/interface.py:529, in EpdeSearch.create_pool(self, data, variable_names, derivs, max_deriv_order, additional_tokens, data_fun_pow)
#     526 entry = InputDataEntry(var_name=variable_names[data_elem_idx],
#     527                          data_tensor=data_tensor)
#     528 derivs_tensor = derivs[data_elem_idx] if derivs is not None else None
# --> 529 entry.set_derivatives(preprocesser=self.preprocessor_pipeline, deriv_tensors=derivs_tensor,
#     530                       grid=global_var.grid_cache.get_all()[1], max_order=max_deriv_order)
#     531 entry.use_global_cache()
#     533 self.set_derivatives(variable=variable_names[data_elem_idx], deriv=entry.derivatives)
#
# File ~/dwn/newenv/lib/python3.10/site-packages/epde/interface/interface.py:87, in InputDataEntry.set_derivatives(self, preprocesser, deriv_tensors, max_order, grid)
#      84 self.d_orders = deriv_orders
#      86 if deriv_tensors is None:
# ---> 87     self.data_tensor, self.derivatives = preprocesser.run(self.data_tensor, grid=grid,
#      88                                                           max_order=max_order)
#      89     self.deriv_properties = {'max order': max_order,
#      90                              'dimensionality': self.data_tensor.ndim}
#      91 else:
#
# File ~/dwn/newenv/lib/python3.10/site-packages/epde/preprocessing/preprocessor.py:138, in PreprocessingPipe.run(self, data, grid, max_order)
#     136 # TODO: add an arbitrary preprocssing operators
#     137 if self.smoother is not None:
# --> 138     data = self.smoother(data, *self.smoother_args,
#     139                          **self.smoother_kwargs)
#     140 return data, self.deriv_calculator(data, *self.deriv_calculator_args, **self.deriv_calculator_kwargs)
#
# File ~/dwn/newenv/lib/python3.10/site-packages/epde/preprocessing/smoothers.py:84, in ANNSmoother.__call__(self, data, grid, epochs_max, loss_mean, batch_frac, learining_rate)
#      80 batch_x, batch_y = grid_flattened[indices], field_[indices]
#      82 loss = torch.mean(torch.abs(batch_y-model(batch_x)))
# ---> 84 loss.backward()
#      85 optimizer.step()
#      86 loss_list.append(loss.item())
#
# File ~/dwn/newenv/lib/python3.10/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/dwn/newenv/lib/python3.10/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
